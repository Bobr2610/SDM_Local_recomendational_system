# %%
import pandas as pd
import numpy as np

# %%
path = 'raw/train_wide.csv'

df = pd.read_csv(path)

df.head()
# Out:
#    user_id sex  age  is_new_customer  seniority_months     income  \
# 0   657788   F   42              0.0               114  132559.35
# 1   657795   M   44              0.0               114   81399.57
# 2   657790   M   42              0.0               114        NaN
# 3   657794   F   49              0.0               114  102189.00
# 4   657789   M   36              0.0                91  153725.49
#
#        segment  dep-7  card-2  dep-5  ...  dep-2  loan-2  card-4  loan-1  \
# 0  INDIVIDUALS      0       1      0  ...      0       0       0       0
# 1  INDIVIDUALS      0       1      0  ...      0       0       0       0
# 2  INDIVIDUALS      0       0      0  ...      0       0       0       0
# 3          VIP      0       1      0  ...      0       0       0       0
# 4          VIP      0       1      0  ...      0       0       0       0
#
#    srv-3  loan-5  biz-4  dep-6  loan-4  card-3
# 0      0       0      0      0       0       0
# ...

# %%
print(*list(df.columns), sep="\n")
# Out:
# user_id
# sex
# age
# is_new_customer
# seniority_months
# income
# segment
# dep-7
# card-2
# dep-5
# card-1
# card-5
# rko-2
# rko-3
# rko-4
# dep-9
# dep-1
# dep-3
# rko-1
# dep-2
# loan-2
# card-4
# loan-1
# srv-3
# loan-5
# biz-4
# dep-6
# loan-4
# card-3

# %%
df.drop(columns=['fecha_dato'], inplace=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.drop(columns=['fecha_dato'], inplace=True)
#       3 df.head()
#
# File ~/code/mai/sdm_hack/venv/lib/python3.9/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df['sex'].isna().sum()
# Out:
# np.int64(3)

# %%
df.dropna(subset=['sex'], inplace=True)

# %%
df['sex'].isna().sum()
# Out:
# np.int64(0)

# %%
df['age'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[df["age"] < 0, "age"] = np.nan

# %%
df['age'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[(df["age"] < 14) | (df["age"] > 95), "age"] = np.nan

# %%
df['age'].isna().sum()
# Out:
# np.int64(3635)

# %%
df.dropna(subset=['age'], inplace=True)

# %%
df['age'].isna().sum()
# Out:
# np.int64(0)

# %%
df['is_new_customer'].isna().sum()
# Out:
# np.int64(0)

# %%
df['is_new_customer'].value_counts()
# Out:
# is_new_customer
# 0.0    354667
# 1.0     17836
# Name: count, dtype: int64

# %%
df['seniority_months'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[df['seniority_months'] < 0, 'seniority_months'] = np.nan

# %%
df['seniority_months'].isna().sum()
# Out:
# np.int64(2)

# %%
df.dropna(subset=['seniority_months'], inplace=True)

# %%
df['seniority_months'].isna().sum()
# Out:
# np.int64(0)

# %%
df['region_code'].isna().sum()
# Out:
# np.int64(0)

# %%
df['region_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['segment'].isna().sum()
# Out:
# np.int64(1438)

# %%
df['segment'] = df['segment'].fillna('UNKNOWN')

# %%
df['segment'].isna().sum()
# Out:
# np.int64(0)

# %%
output_path = 'processed/v1/train_wide_cleaned.csv'

df.to_csv(output_path, index=False)
